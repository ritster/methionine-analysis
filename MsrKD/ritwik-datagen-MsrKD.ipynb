# %% [markdown]
# ## Imports

# %%
# General imports 
import pandas as pd
import numpy as np
import os
import re
import plotly.express as px
from tqdm import tqdm
import tempfile
import csv
import requests as r
from Bio import SeqIO
from io import StringIO
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
import warnings

warnings.filterwarnings('ignore')

# Import structuremap functions
import structuremap.utils
structuremap.utils.set_logger()
from structuremap.processing import download_alphafold_cif, download_alphafold_pae, format_alphafold_data, annotate_accessibility, get_smooth_score, annotate_proteins_with_idr_pattern, get_extended_flexible_pattern, get_proximity_pvals, perform_enrichment_analysis, perform_enrichment_analysis_per_protein, evaluate_ptm_colocalization, extract_motifs_in_proteome
from structuremap.plotting import plot_enrichment, plot_ptm_colocalization

# %% [markdown]
# ## Set Parameters of Analysis

# %%
analysis_threshold = 20 # number of amino acids either side to analyze

modifications = ["649.3660", "655.3735"] # which modifications we are looking for, as regex strings
heavy_modification = "655.3735" 
light_modification = "649.3660"

# %% [markdown]
# ## Load Dataset - MsrAKD

# %%
# path for csv output data
datasets_path_str = "../datasets/"
datasets_path = os.path.abspath(datasets_path_str)
print(datasets_path)

# %%
data_loc = os.path.join(datasets_path, "05_10_24_293T_MsrKD_data.xlsx")
peptides = pd.read_excel(data_loc, sheet_name="293T_MsrAKD_quant")
peptides

# %%
# Canonicalize data - none to do here
peptides;

# %%
label_col_data = ["blue"] * 157 + ["green"] * 381 + ["white"] * 9 + ["red"] * 12 + ["gray"] * 104
label_col = pd.Series(label_col_data)
peptides["color"] = label_col

#pd.set_option("display.max_rows", None)
display(peptides)
#pd.reset_option("display.max_rows")

# %%
peptides_completed_sequence = peptides.copy()

# %% [markdown]
# # Download Alphafold Data - MsrAKD

# %%
# path for alphafold protein data
alphafold_path_str = "../alphafold_data/"
alphafold_path = os.path.abspath(alphafold_path_str)

cif_dir = os.path.join(alphafold_path, "cif")
pae_dir = os.path.join(alphafold_path, "pae")

print(alphafold_path)
print(cif_dir)
print(pae_dir)

# %%
# set uniprot IDs to use
uniprotIDs = peptides_completed_sequence["Protein ID"].unique()
uniprotIDs, len(uniprotIDs)

# %%
# download cif data for proteins
# SLOW THE FIRST TIME
valid_proteins_cif, invalid_proteins_cif, existing_proteins_cif = download_alphafold_cif(
    proteins=uniprotIDs,
    out_folder=cif_dir
)

# %%
# download pae data for proteins
# SLOW THE FIRST TIME
valid_proteins_pae, invalid_proteins_pae, existing_proteins_pae = download_alphafold_pae(
    proteins=uniprotIDs,
    out_folder=pae_dir, 
)

# %%
invalid_proteins_pae

# %%
peptides_completed_sequence[peptides_completed_sequence["Protein ID"].isin(invalid_proteins_pae)]

# %% [markdown]
# ## Load Dataset - MsrBKD

# %%
# path for csv output data
datasets_path_str = "../datasets/"
datasets_path = os.path.abspath(datasets_path_str)
print(datasets_path)
# Out:
# /Users/ritwiksrinivas/Desktop/Projects/methionine-analysis/datasets

# %%
data_loc = os.path.join(datasets_path, "05_10_24_293T_MsrKD_data.xlsx")
peptides = pd.read_excel(data_loc, sheet_name="293T_MsrB2KD_quant")
peptides
# Out:
#           Light Modified Peptide       Heavy Modified Peptide  \
# 0       FAGLHFFNPVPVM[649.3660]K     FAGLHFFNPVPVM[655.3735]K
# 1            IGM[649.3660]SVNAIR          IGM[655.3735]SVNAIR
# 2        KMEM[649.3660]EMEQVFEMK      KMEM[655.3735]EMEQVFEMK
# 3          LRLEVNLQAM[649.3660]K        LRLEVNLQAM[655.3735]K
# 4    AASDIAM[649.3660]TELPPTHPIR  AASDIAM[655.3735]TELPPTHPIR
# ..                           ...                          ...
# 749        DQGLSIM[649.3660]VSGK        DQGLSIM[655.3735]VSGK
# 750         EAM[649.3660]NHPGHLK         EAM[655.3735]NHPGHLK
# 751          ALEEAM[649.3660]EQK          ALEEAM[655.3735]EQK
# 752       VTM[649.3660]LFLGLHNVR       VTM[655.3735]LFLGLHNVR
# 753  LQHVEDGVLSM[649.3660]QVASAR  LQHVEDGVLSM[655.3735]QVASAR
#
#      MsrB2_KD_1 Log2 Ratio HL  MsrB2_KD_10 Log2 Ratio HL  \
# 0                   -4.205662                  -3.548803
# 1                         NaN                        NaN
# 2                   -2.274200                  -2.855665
# 3                         NaN                        NaN
# 4                   -2.630824                        NaN
# ..                        ...                        ...
# 749                       NaN                   2.936602
# 750                       NaN                        NaN
# 751                  2.683003                        NaN
# 752                       NaN                        NaN
# 753                       NaN                        NaN
#
#      MsrB2_KD_11 Log2 Ratio HL  MsrB2_KD_12 Log2 Ratio HL  \
# 0                    -4.189766                  -4.160031
# 1                          NaN                  -4.399577
# 2                    -2.947620                  -2.942285
# 3                          NaN                        NaN
# 4                    -2.145969                  -1.169837
# ..                         ...                        ...
# 749                        NaN                        NaN
# 750                        NaN                        NaN
# 751                   3.269254                        NaN
# 752                        NaN                        NaN
# 753                        NaN                        NaN
#
#      MsrB2_KD_2 Log2 Ratio HL  MsrB2_KD_3 Log2 Ratio HL  \
# 0                   -4.436141                 -3.632403
# 1                         NaN                 -3.417119
# 2                   -3.161963                 -2.854557
# 3                         NaN                       NaN
# 4                         NaN                 -2.919210
# ..                        ...                       ...
# 749                       NaN                       NaN
# 750                       NaN                       NaN
# 751                       NaN                       NaN
# 752                       NaN                       NaN
# 753                       NaN                       NaN
#
#      MsrB2_KD_4 Log2 Ratio HL  MsrB2_KD_5 Log2 Ratio HL  ...  Protein ID  \
# 0                   -3.887475                 -4.186961  ...      Q16836
# 1                   -3.768051                       NaN  ...      P23193
# 2                   -2.779239                 -2.276797  ...      Q16181
# 3                   -2.033939                       NaN  ...      P35579
# 4                         NaN                       NaN  ...      P62258
# ..                        ...                       ...  ...         ...
# 749                       NaN                       NaN  ...      Q00341
# 750                       NaN                       NaN  ...      P00374
# 751                       NaN                       NaN  ...      P35579
# 752                  2.743130                       NaN  ...      P14868
# 753                  6.256636                  5.079367  ...      Q07065
#
#       Entry Name     Gene                                Protein Description  \
# 0     HCDH_HUMAN     HADH  Hydroxyacyl-coenzyme A dehydrogenase, mitochon...
# 1    TCEA1_HUMAN    TCEA1        Transcription elongation factor A protein 1
# 2    SEPT7_HUMAN  SEPTIN7                                           Septin-7
# 3     MYH9_HUMAN     MYH9                                           Myosin-9
# 4    1433E_HUMAN    YWHAE                             14-3-3 protein epsilon
# ..           ...      ...                                                ...
# 749  VIGLN_HUMAN    HDLBP                                            Vigilin
# 750    DYR_HUMAN     DHFR                            Dihydrofolate reductase
# 751   MYH9_HUMAN     MYH9                                           Myosin-9
# 752   SYDC_HUMAN    DARS1                Aspartate--tRNA ligase, cytoplasmic
# 753  CKAP4_HUMAN    CKAP4                  Cytoskeleton-associated protein 4
#
#            pvalue    neglogp Log2HL avg Site Number   Site       Label
# 0    7.317853e-14  13.135616  -4.116590         178   M178   HCDH_M178
# 1    3.213832e-04   3.492977  -3.852951          48    M48   TCEA1_M48
# 2    2.521873e-11  10.598277  -2.655733         355   M355  SEPT7_M355
# 3    2.469697e-03   2.607356  -2.118498        1565  M1565  MYH9_M1565
# 4    3.952954e-03   2.403078  -2.045838         160   M160  1433E_M160
# ..            ...        ...        ...         ...    ...         ...
# 749  1.332075e-01   0.875471   2.654099         128   M128  VIGLN_M128
# 750  5.244905e-02   1.280262   2.951996         126   M126    DYR_M126
# 751  6.250049e-02   1.204117   2.976128        1489  M1489  MYH9_M1489
# 752  6.321136e-02   1.199205   3.046635         478   M478   SYDC_M478
# 753  6.587816e-02   1.181259   5.668001         423   M423  CKAP4_M423
#
# [754 rows x 25 columns]

# %%
# Canonicalize data - none to do here
peptides;

# %%
label_col_data = ["blue"] * 10 + ["white"] * 30 + ["green"] * 381 + ["red"] * 213 + ["gray"] * 120
label_col = pd.Series(label_col_data)
peptides["color"] = label_col

#pd.set_option("display.max_rows", None)
display(peptides)
#pd.reset_option("display.max_rows")
# Out:
#           Light Modified Peptide       Heavy Modified Peptide  \
# 0       FAGLHFFNPVPVM[649.3660]K     FAGLHFFNPVPVM[655.3735]K
# 1            IGM[649.3660]SVNAIR          IGM[655.3735]SVNAIR
# 2        KMEM[649.3660]EMEQVFEMK      KMEM[655.3735]EMEQVFEMK
# 3          LRLEVNLQAM[649.3660]K        LRLEVNLQAM[655.3735]K
# 4    AASDIAM[649.3660]TELPPTHPIR  AASDIAM[655.3735]TELPPTHPIR
# ..                           ...                          ...
# 749        DQGLSIM[649.3660]VSGK        DQGLSIM[655.3735]VSGK
# 750         EAM[649.3660]NHPGHLK         EAM[655.3735]NHPGHLK
# 751          ALEEAM[649.3660]EQK          ALEEAM[655.3735]EQK
# 752       VTM[649.3660]LFLGLHNVR       VTM[655.3735]LFLGLHNVR
# 753  LQHVEDGVLSM[649.3660]QVASAR  LQHVEDGVLSM[655.3735]QVASAR
#
#      MsrB2_KD_1 Log2 Ratio HL  MsrB2_KD_10 Log2 Ratio HL  \
# 0                   -4.205662                  -3.548803
# 1                         NaN                        NaN
# 2                   -2.274200                  -2.855665
# 3                         NaN                        NaN
# 4                   -2.630824                        NaN
# ..                        ...                        ...
# 749                       NaN                   2.936602
# 750                       NaN                        NaN
# 751                  2.683003                        NaN
# 752                       NaN                        NaN
# 753                       NaN                        NaN
#
#      MsrB2_KD_11 Log2 Ratio HL  MsrB2_KD_12 Log2 Ratio HL  \
# 0                    -4.189766                  -4.160031
# 1                          NaN                  -4.399577
# 2                    -2.947620                  -2.942285
# 3                          NaN                        NaN
# 4                    -2.145969                  -1.169837
# ..                         ...                        ...
# 749                        NaN                        NaN
# 750                        NaN                        NaN
# 751                   3.269254                        NaN
# 752                        NaN                        NaN
# 753                        NaN                        NaN
#
#      MsrB2_KD_2 Log2 Ratio HL  MsrB2_KD_3 Log2 Ratio HL  \
# 0                   -4.436141                 -3.632403
# 1                         NaN                 -3.417119
# 2                   -3.161963                 -2.854557
# 3                         NaN                       NaN
# 4                         NaN                 -2.919210
# ..                        ...                       ...
# 749                       NaN                       NaN
# 750                       NaN                       NaN
# 751                       NaN                       NaN
# 752                       NaN                       NaN
# 753                       NaN                       NaN
#
#      MsrB2_KD_4 Log2 Ratio HL  MsrB2_KD_5 Log2 Ratio HL  ...   Entry Name  \
# 0                   -3.887475                 -4.186961  ...   HCDH_HUMAN
# 1                   -3.768051                       NaN  ...  TCEA1_HUMAN
# 2                   -2.779239                 -2.276797  ...  SEPT7_HUMAN
# 3                   -2.033939                       NaN  ...   MYH9_HUMAN
# 4                         NaN                       NaN  ...  1433E_HUMAN
# ..                        ...                       ...  ...          ...
# 749                       NaN                       NaN  ...  VIGLN_HUMAN
# 750                       NaN                       NaN  ...    DYR_HUMAN
# 751                       NaN                       NaN  ...   MYH9_HUMAN
# 752                  2.743130                       NaN  ...   SYDC_HUMAN
# 753                  6.256636                  5.079367  ...  CKAP4_HUMAN
#
#         Gene                                Protein Description        pvalue  \
# 0       HADH  Hydroxyacyl-coenzyme A dehydrogenase, mitochon...  7.317853e-14
# 1      TCEA1        Transcription elongation factor A protein 1  3.213832e-04
# 2    SEPTIN7                                           Septin-7  2.521873e-11
# 3       MYH9                                           Myosin-9  2.469697e-03
# 4      YWHAE                             14-3-3 protein epsilon  3.952954e-03
# ..       ...                                                ...           ...
# 749    HDLBP                                            Vigilin  1.332075e-01
# 750     DHFR                            Dihydrofolate reductase  5.244905e-02
# 751     MYH9                                           Myosin-9  6.250049e-02
# 752    DARS1                Aspartate--tRNA ligase, cytoplasmic  6.321136e-02
# 753    CKAP4                  Cytoskeleton-associated protein 4  6.587816e-02
#
#        neglogp Log2HL avg Site Number   Site       Label  color
# 0    13.135616  -4.116590         178   M178   HCDH_M178   blue
# 1     3.492977  -3.852951          48    M48   TCEA1_M48   blue
# 2    10.598277  -2.655733         355   M355  SEPT7_M355   blue
# 3     2.607356  -2.118498        1565  M1565  MYH9_M1565   blue
# 4     2.403078  -2.045838         160   M160  1433E_M160   blue
# ..         ...        ...         ...    ...         ...    ...
# 749   0.875471   2.654099         128   M128  VIGLN_M128   gray
# 750   1.280262   2.951996         126   M126    DYR_M126   gray
# 751   1.204117   2.976128        1489  M1489  MYH9_M1489   gray
# 752   1.199205   3.046635         478   M478   SYDC_M478   gray
# 753   1.181259   5.668001         423   M423  CKAP4_M423   gray
#
# [754 rows x 26 columns]

# %%
peptides_completed_sequence = peptides.copy()

# %% [markdown]
# # Download Alphafold Data - MsrB2KD

# %%
# path for alphafold protein data
alphafold_path_str = "../alphafold_data/"
alphafold_path = os.path.abspath(alphafold_path_str)

cif_dir = os.path.join(alphafold_path, "cif")
pae_dir = os.path.join(alphafold_path, "pae")

print(alphafold_path)
print(cif_dir)
print(pae_dir)
# Out:
# /Users/ritwiksrinivas/Desktop/Projects/methionine-analysis/alphafold_data
# /Users/ritwiksrinivas/Desktop/Projects/methionine-analysis/alphafold_data/cif
# /Users/ritwiksrinivas/Desktop/Projects/methionine-analysis/alphafold_data/pae

# %%
# set uniprot IDs to use
uniprotIDs = peptides_completed_sequence["Protein ID"].unique()
uniprotIDs, len(uniprotIDs)
# Out:
# (array(['Q16836', 'P23193', 'Q16181', 'P35579', 'P62258', 'P46109',
#         'P55072', 'Q9Y265', 'P25205', 'P61024', 'P41227', 'P18583',
#         'Q9UN37', 'O14744', 'Q86UP2', 'O14874', 'P36543', 'Q9Y2W2',
#         'P14174', 'Q9Y617', 'Q8WVK2', 'P31948', 'Q9Y3U8', 'Q99729',
#         'Q9UKD2', 'Q9Y3I0', 'P27144', 'Q9UHX1', 'P22307', 'Q01518',
#         'Q9BWF3', 'Q9Y580', 'O43707', 'P22061', 'P52272', 'Q9HD42',
#         'P50454', 'O95831', 'P18859', 'P05067', 'P60709', 'P68032',
#         'P35611', 'P55196', 'Q4VCS5', 'P08243', 'P05023', 'P24539',
#         'Q9NVI7', 'Q8WWM7', 'Q07812', 'Q9NYF8', 'Q9UHR4', 'P11021',
#         'Q9BRK5', 'O43852', 'Q14444', 'Q96CT7', 'Q16543', 'P06493',
#         'P61604', 'P10809', 'Q9UQN3', 'Q9H444', 'Q9Y3Y2', 'Q14011',
#         'E9PRG8', 'Q07065', 'Q15003', 'P09669', 'P33240', 'Q9H0L4',
#         'Q92841', 'Q9NR30', 'Q9BUQ8', 'P00367', 'Q08211', 'Q99615',
#         'O75937', 'P55265', 'P33316', 'Q14204', 'P55084', 'P42126',
#         'Q6P2E9', 'P29692', 'Q14152', 'O75821', 'O15372', 'Q09666',
#         'Q15717', 'Q8N8S7', 'P06733', 'P14625', 'O43768', 'P15170',
#         'Q01844', 'P15311', 'Q02790', 'Q96AE4', 'P35637', 'Q13283',
#         'Q9UN86', 'P14314', 'P46926', 'Q14789', 'P38646', 'Q9BZE4',
#         'P49915', 'P62805', 'O00165', 'P82970', 'P30519', 'P31943',
#         'P31942', 'P07910', 'P52597', 'P61978', 'P14866', 'Q00839',
#         'P07900', 'P08238', 'P11142', 'Q9Y4L1', 'Q14197', 'Q9NZI8',
#         'P38919', 'Q04637', 'Q15056', 'Q12906', 'P52292', 'P12268',
#         'Q9H910', 'Q14CN4', 'Q07666', 'P33176', 'Q92615', 'Q6PKG0',
#         'Q9Y383', 'P07195', 'Q04760', 'O75334', 'P43034', 'P49257',
#         'P02545', 'P20700', 'Q03252', 'Q8IWC1', 'P46821', 'P27816',
#         'P43243', 'Q15648', 'Q14696', 'P26038', 'O43347', 'Q9P2K5',
#         'Q8N183', 'Q9BPW8', 'Q15233', 'Q99733', 'P06748', 'Q9UNZ2',
#         'P49790', 'P80303', 'Q9Y266', 'P52948', 'P54886', 'Q8WXI9',
#         'P11940', 'Q13310', 'Q15366', 'O14737', 'P61758', 'P18669',
#         'O60664', 'O43660', 'Q9Y520', 'Q8WWY3', 'Q6P2Q9', 'O43395',
#         'O00487', 'Q8WXF1', 'Q14671', 'P63244', 'P98175', 'Q96PK6',
#         'Q9NW64', 'P49756', 'Q5T8P6', 'Q14498', 'P38159', 'P54727',
#         'Q13123', 'Q9BZI7', 'Q92900', 'Q6WKZ4', 'P27635', 'P26373',
#         'P40429', 'P84098', 'P46778', 'P62829', 'P62750', 'P83731',
#         'P61254', 'P47914', 'P39023', 'P62910', 'P46777', 'Q15287',
#         'P09651', 'P46783', 'P62841', 'P62847', 'P62854', 'P62857',
#         'P62861', 'P61247', 'P62081', 'Q7L4I2', 'P82650', 'Q92665',
#         'P82930', 'P08621', 'A8MWD9', 'Q15424', 'Q14151', 'O75396',
#         'Q15019', 'Q8NC51', 'Q15637', 'O75533', 'Q13435', 'P23246',
#         'Q9NWH9', 'Q14683', 'O95347', 'Q9UQE7', 'Q969G3', 'P62318',
#         'Q92922', 'O95721', 'O43290', 'Q13573', 'Q07889', 'P52788',
#         'Q7KZ85', 'Q13813', 'P37108', 'P61011', 'O76094', 'Q04837',
#         'P43308', 'P16949', 'Q8IX01', 'O43776', 'P47897', 'P37802',
#         'Q71U36', 'P07437', 'Q13428', 'P53999', 'P78371', 'P48643',
#         'P49368', 'P50990', 'O14776', 'Q9UBB9', 'Q96EK4', 'Q86V81',
#         'Q13263', 'Q9Y490', 'Q7L0Y3', 'Q8WUH6', 'Q9Y2S6', 'Q9UKE5',
#         'O96008', 'P12270', 'Q56UQ5', 'Q9Y2W1', 'Q13595', 'P62995',
#         'Q12931', 'Q9BQ61', 'P40222', 'O75643', 'Q13404', 'Q9UHD9',
#         'Q04323', 'Q16864', 'P08670', 'P55060', 'P67809', 'Q9BW85',
#         'P49750', 'Q9Y5A9', 'Q5BKZ1', 'Q9UG63', 'P12814', 'Q8N6H7',
#         'O95817', 'P51572', 'Q00587', 'Q05682', 'Q9NXV6', 'Q92793',
#         'Q16204', 'P41208', 'P57076', 'Q9UEE9', 'Q8IWX8', 'O43633',
#         'Q8TCG1', 'Q9NZN8', 'O75208', 'Q16630', 'P12074', 'Q9HB71',
#         'O00571', 'Q7Z478', 'O60610', 'Q9NVH1', 'O60884', 'Q9BPU6',
#         'O43491', 'Q99848', 'P68104', 'O15371', 'P60228', 'Q9H9T3',
#         'Q14320', 'Q14254', 'Q92945', 'P04406', 'P63218', 'Q8IXQ4',
#         'P69905', 'P0DMV8', 'O95757', 'Q6YN16', 'Q7Z5L9', 'P60842',
#         'Q96LB3', 'P52294', 'P41236', 'O14654', 'Q96ST2', 'O60271',
#         'P46013', 'P05455', 'Q8WZA0', 'P49736', 'Q16891', 'O94851',
#         'Q15773', 'P13995', 'Q15596', 'P56556', 'P07197', 'O15226',
#         'Q13823', 'P46459', 'Q02818', 'Q14980', 'Q7Z3B4', 'P12694',
#         'Q9UQ80', 'Q15365', 'Q9UHV9', 'Q9H7Z7', 'Q99623', 'Q9H307',
#         'Q12972', 'O75400', 'P17980', 'P62195', 'P25786', 'Q99436',
#         'Q8IUD2', 'Q9NTZ6', 'Q14257', 'P18621', 'P46779', 'P62899',
#         'P22626', 'P51991', 'Q9Y2L1', 'Q15050', 'O43865', 'P82979',
#         'Q15020', 'O94979', 'O95104', 'Q15047', 'O00193', 'P51532',
#         'O60749', 'Q01082', 'O15042', 'Q9BXP5', 'Q9NUL3', 'Q96SI9',
#         'P07814', 'Q96EI5', 'P50991', 'Q99598', 'Q9NRR5', 'P15374',
#         'P18206', 'Q2M389', 'Q9C0J8', 'Q9BYJ9', 'Q96KR1', 'Q9ULT8',
#         'Q16777', 'Q96PU8', 'O00232', 'Q7L7X3', 'P67870', 'Q9NRG7',
#         'Q9UMX0', 'Q8N1G2', 'Q99832', 'P08579', 'Q9H7E9', 'P09496',
#         'Q92805', 'Q9NP97', 'Q14839', 'P07108', 'O43252', 'P22830',
#         'Q9NUU7', 'P82675', 'Q9Y237', 'P0DP23', 'Q16643', 'Q9UKV3',
#         'P61353', 'P20290', 'P07954', 'O60684', 'Q06787', 'Q96I24',
#         'Q9BQI0', 'O75534', 'Q9NX40', 'O00233', 'P61619', 'Q9NU22',
#         'O94906', 'Q9BY77', 'Q04721', 'Q15417', 'Q13442', 'Q9UNZ5',
#         'Q8WUM0', 'P18858', 'O95835', 'P16989', 'P49959', 'Q00341',
#         'P00374', 'P14868'], dtype=object),
#  464)

# %%
# download cif data for proteins
# SLOW THE FIRST TIME
valid_proteins_cif, invalid_proteins_cif, existing_proteins_cif = download_alphafold_cif(
    proteins=uniprotIDs,
    out_folder=cif_dir
)
# Out:
# 100%|██████████| 464/464 [01:18<00:00,  5.94it/s]
# 2024-05-19 19:43:54> Valid proteins: 27
# 2024-05-19 19:43:54> Invalid proteins: 6
# 2024-05-19 19:43:54> Existing proteins: 431

# %%
# download pae data for proteins
# SLOW THE FIRST TIME
valid_proteins_pae, invalid_proteins_pae, existing_proteins_pae = download_alphafold_pae(
    proteins=uniprotIDs,
    out_folder=pae_dir, 
)
# Out:
# 100%|██████████| 464/464 [01:23<00:00,  5.57it/s]
# 2024-05-19 19:45:18> Valid proteins: 27
# 2024-05-19 19:45:18> Invalid proteins: 6
# 2024-05-19 19:45:18> Existing proteins: 431

# %%
invalid_proteins_pae
# Out:
# ['Q14204', 'Q09666', 'Q14789', 'Q9Y520', 'P46013', 'Q9NU22']

# %%
peptides_completed_sequence[peptides_completed_sequence["Protein ID"].isin(invalid_proteins_pae)]
# Out:
#           Light Modified Peptide       Heavy Modified Peptide  \
# 97    RSELEEQQM[649.3660]HLNVGLR   RSELEEQQM[655.3735]HLNVGLR
# 108     ISM[649.3660]PDIDLNLKGPK     ISM[655.3735]PDIDLNLKGPK
# 130         AFQIM[649.3660]QEELR         AFQIM[655.3735]QEELR
# 248           M[649.3660]NSIVYQK           M[655.3735]NSIVYQK
# 253        ISM[649.3660]PDVDLHLK        ISM[655.3735]PDVDLHLK
# 462          INM[649.3660]LVIELK          INM[655.3735]LVIELK
# 463           M[649.3660]VVLSLPR           M[655.3735]VVLSLPR
# 504      AM[649.3660]HTPKPAVGEEK      AM[655.3735]HTPKPAVGEEK
# 552  GLIPAGTQHSM[649.3660]IATTGK  GLIPAGTQHSM[655.3735]IATTGK
# 719           SM[649.3660]GDHNER           SM[655.3735]GDHNER
# 726            AFM[649.3660]ESPK            AFM[655.3735]ESPK
# 743        ISM[649.3660]PDFDLHLK        ISM[655.3735]PDFDLHLK
#
#      MsrB2_KD_1 Log2 Ratio HL  MsrB2_KD_10 Log2 Ratio HL  \
# 97                   1.979056                   1.859028
# 108                       NaN                        NaN
# 130                  1.059465                   1.217048
# 248                  1.428400                        NaN
# 253                  2.023708                        NaN
# 462                  1.651044                   1.464602
# 463                  2.074851                   2.450636
# 504                       NaN                   0.840213
# 552                       NaN                        NaN
# 719                       NaN                        NaN
# 726                       NaN                        NaN
# 743                       NaN                        NaN
#
#      MsrB2_KD_11 Log2 Ratio HL  MsrB2_KD_12 Log2 Ratio HL  \
# 97                    1.810054                   1.872240
# 108                   2.317727                   1.315954
# 130                   1.227890                   1.415169
# 248                   2.302641                        NaN
# 253                   1.388773                        NaN
# 462                        NaN                        NaN
# 463                   1.930566                   2.136952
# 504                        NaN                        NaN
# 552                        NaN                        NaN
# 719                   1.642751                        NaN
# 726                        NaN                        NaN
# 743                   1.440875                        NaN
#
#      MsrB2_KD_2 Log2 Ratio HL  MsrB2_KD_3 Log2 Ratio HL  \
# 97                   1.952729                  2.033539
# 108                  2.486824                  2.297093
# 130                  1.178414                  1.124770
# 248                       NaN                       NaN
# 253                       NaN                       NaN
# 462                       NaN                  1.581897
# 463                       NaN                  2.123057
# 504                       NaN                       NaN
# 552                  1.775794                  1.826232
# 719                       NaN                       NaN
# 726                       NaN                       NaN
# 743                       NaN                       NaN
#
#      MsrB2_KD_4 Log2 Ratio HL  MsrB2_KD_5 Log2 Ratio HL  ...   Entry Name  \
# 97                   1.941938                  1.988914  ...  DYHC1_HUMAN
# 108                       NaN                  2.372561  ...   AHNK_HUMAN
# 130                  1.382358                  1.389273  ...  GOGB1_HUMAN
# 248                       NaN                  1.752522  ...  PRC2C_HUMAN
# 253                  2.040480                  1.427990  ...   AHNK_HUMAN
# 462                       NaN                       NaN  ...  DYHC1_HUMAN
# 463                  2.228832                  1.589716  ...  DYHC1_HUMAN
# 504                  1.688776                  2.119348  ...   KI67_HUMAN
# 552                  1.304407                       NaN  ...  PRC2C_HUMAN
# 719                       NaN                       NaN  ...   MDN1_HUMAN
# 726                  1.880089                       NaN  ...   KI67_HUMAN
# 743                       NaN                  2.785689  ...   AHNK_HUMAN
#
#         Gene                                Protein Description        pvalue  \
# 97   DYNC1H1                 Cytoplasmic dynein 1 heavy chain 1  1.020051e-10
# 108    AHNAK  Neuroblast differentiation-associated protein ...  5.110537e-06
# 130   GOLGB1                        Golgin subfamily B member 1  1.497988e-12
# 248   PRRC2C                                     Protein PRRC2C  1.036683e-03
# 253    AHNAK  Neuroblast differentiation-associated protein ...  2.795943e-04
# 462  DYNC1H1                 Cytoplasmic dynein 1 heavy chain 1  6.641485e-05
# 463  DYNC1H1                 Cytoplasmic dynein 1 heavy chain 1  3.335842e-08
# 504    MKI67                 Proliferation marker protein Ki-67  2.047267e-03
# 552   PRRC2C                                     Protein PRRC2C  5.141039e-05
# 719     MDN1                                            Midasin  8.398708e-02
# 726    MKI67                 Proliferation marker protein Ki-67  1.195096e-01
# 743    AHNAK  Neuroblast differentiation-associated protein ...  1.961122e-01
#
#        neglogp Log2HL avg Site Number   Site        Label  color
# 97    9.991378   2.025697        3199  M3199  DYHC1_M3199  green
# 108   5.291533   2.072387           0     M0      AHNK_M0  green
# 130  11.824492   1.246823        2934  M2934  GOGB1_M2934  green
# 248   2.984354   1.915040        2702  M2702  PRC2C_M2702  green
# 253   3.553472   1.695889           0     M0      AHNK_M0  green
# 462   4.177735   1.438639        1398  M1398  DYHC1_M1398    red
# 463   7.476795   1.993457         991   M991   DYHC1_M991    red
# 504   2.688826   1.691246        1782  M1782   KI67_M1782    red
# 552   4.288949   1.643852        2648  M2648  PRC2C_M2648    red
# 719   1.075788   1.450300        5110  M5110   MDN1_M5110   gray
# 726   0.922597   1.579957        1677  M1677   KI67_M1677   gray
# 743   0.707495   2.113282           0     M0      AHNK_M0   gray
#
# [12 rows x 26 columns]
