# %%
from ramachandraw.utils import fetch_pdb
from ramachandraw.utils import plot
import pandas as pd

# %%
pdb_ids = pd.read_csv('../datasets/idmapping_2024_04_18.tsv', sep='\t')

# %%
pdb_ids
# Out:
#       From    To
# 0   P50247  5AXA
# 1   P50247  5AXB
# 2   P50247  5AXC
# 3   P50247  5AXD
# 4   P47962  6SWA
# ..     ...   ...
# 87  Q01853  2PJH
# 88  Q01853  3CF0
# 89  Q01853  3CF1
# 90  Q01853  3CF2
# 91  Q01853  3CF3
#
# [92 rows x 2 columns]

# %%
pdb_id = "3CF0"

# Draw the Ramachandran plot
plot(fetch_pdb(pdb_id))
# Out:
# <Axes: title={'center': '.pdb/pdb3cf0.ent'}, xlabel='φ', ylabel='ψ'>
